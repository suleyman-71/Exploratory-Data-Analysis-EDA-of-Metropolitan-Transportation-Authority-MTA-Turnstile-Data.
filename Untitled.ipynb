# %%
import glob
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns

# %%
list_of_files = glob.glob('*.txt')

file_list = []

for filename in list_of_files:
    df = pd.read_csv(filename)
    file_list.append(df)
    
mta = pd.concat(file_list)

# %%
mta.head(15)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2021  00:00:00
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2021  04:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2021  08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2021  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2021  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2021  20:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/30/2021  00:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/30/2021  04:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/30/2021  08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/30/2021  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/30/2021  16:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/30/2021  20:00:00
# ...

# %%
mta.shape
# Out:
# (3443960, 11)

# %%
mta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3443960 entries, 0 to 210399
# Data columns (total 11 columns):
#  #   Column                                                                Dtype
# ---  ------                                                                -----
#  0   C/A                                                                   object
#  1   UNIT                                                                  object
#  2   SCP                                                                   object
#  3   STATION                                                               object
#  4   LINENAME                                                              object
#  5   DIVISION                                                              object
#  6   DATE                                                                  object
#  7   TIME                                                                  object
# ...

# %%
mta.columns = mta.columns.str.strip()
mta.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
mta["TURNSTILE"] = mta["C/A"]+"-"+mta["UNIT"]+"-"+mta["SCP"]

mta['DATETIME'] = mta["DATE"]+ " " + mta["TIME"]

mta['DATETIME'] = pd.to_datetime(mta['DATETIME'], format='%m/%d/%Y %H:%M:%S')

mta["NAMEOFDAY"]= mta["DATETIME"].dt.day_name()

mta = mta[["STATION","TURNSTILE","DATETIME","NAMEOFDAY","ENTRIES","EXITS"]]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-15-d0db010578cc> in <module>
#       7 mta["NAMEOFDAY"]= mta["DATETIME"].dt.day_name()
#       8
# ----> 9 mta = mta[["STATION","TURNSTILE","DATETIME","NAMEOFDAY","ENTRIES","EXITS"]]
#
# C:\Program Files\anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2912             indexer = np.where(indexer)[0]
#    2913
# -> 2914         data = self._take_with_is_copy(indexer, axis=1)
#    2915
#    2916         if is_single_key:
#
# C:\Program Files\anaconda\lib\site-packages\pandas\core\generic.py in _take_with_is_copy(self, indices, axis)
#    3361         See the docstring of `take` for full explanation of the parameters.
#    3362         """
# -> 3363         result = self.take(indices=indices, axis=axis)
#    3364         # Maybe set copy if we didn't actually change the index.
# ...

# %%
mta.head(10)
